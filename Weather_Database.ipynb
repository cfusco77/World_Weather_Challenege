# %%
#Get the weather description and amount of precipitation for each city 
from citipy import citipy
import numpy as np 
import pandas as pd

# %%
#Create a set of random latitudes and longitude combinations 
lats = np.random.uniform(low = -90.000 , high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats, lngs)

# %%
#add the latitudes and longitudes to a list 
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 610

# %%
#import the request library 
import requests 
from datetime import datetime 
from config import weather_api_key 

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | half moon bay
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | caravelas
# Processing Record 4 of Set 1 | adrar
# Processing Record 5 of Set 1 | vostok
# Processing Record 6 of Set 1 | srednekolymsk
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | oussouye
# Processing Record 10 of Set 1 | acarau
# Processing Record 11 of Set 1 | port alberni
# Processing Record 12 of Set 1 | altus
# Processing Record 13 of Set 1 | vao
# Processing Record 14 of Set 1 | carlos antonio lopez
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | kutum
# Processing Record 17 of Set 1 | narsaq
# Processing Record 18 of Set 1 | taunggyi
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | lerwick
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | ixtapa
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | college
# Processing Record 27 of Set 1 | mouzouras
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | yar-sale
# Processing Record 32 of Set 1 | ambilobe
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | kieta
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | kingaroy
# Processing Record 40 of Set 1 | lorengau
# Processing Record 41 of Set 1 | bengkulu
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 44 of Set 1 | bafra
# Processing Record 45 of Set 1 | san quintin
# Processing Record 46 of Set 1 | cayenne
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | esperance
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | izberbash
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | sao filipe
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | soyo
# Processing Record 11 of Set 2 | grindavik
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | hauge
# Processing Record 15 of Set 2 | bonfim
# Processing Record 16 of Set 2 | catumbela
# Processing Record 17 of Set 2 | itoman
# Processing Record 18 of Set 2 | lazaro cardenas
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | jingdezhen
# Processing Record 21 of Set 2 | dibaya
# City not found. Skipping...
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | cleveland
# Processing Record 26 of Set 2 | zabaykalsk
# Processing Record 27 of Set 2 | carlsbad
# Processing Record 28 of Set 2 | zhuhai
# Processing Record 29 of Set 2 | bonavista
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | pevek
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | tank
# Processing Record 37 of Set 2 | pandan
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | pochutla
# Processing Record 41 of Set 2 | vanimo
# Processing Record 42 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 2 | berlevag
# Processing Record 44 of Set 2 | severodvinsk
# Processing Record 45 of Set 2 | vila velha
# Processing Record 46 of Set 2 | fort nelson
# Processing Record 47 of Set 2 | fairbanks
# Processing Record 48 of Set 2 | harper
# Processing Record 49 of Set 2 | aksarka
# Processing Record 50 of Set 2 | grand gaube
# Processing Record 1 of Set 3 | guerrero negro
# Processing Record 2 of Set 3 | touros
# Processing Record 3 of Set 3 | marawi
# Processing Record 4 of Set 3 | lagoa
# Processing Record 5 of Set 3 | koping
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | buala
# Processing Record 8 of Set 3 | pinega
# Processing Record 9 of Set 3 | isangel
# Processing Record 10 of Set 3 | tiksi
# Processing Record 11 of Set 3 | hauzenberg
# Processing Record 12 of Set 3 | shache
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | salalah
# Processing Record 15 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 3 | makung
# City not found. Skipping...
# Processing Record 17 of Set 3 | hailun
# Processing Record 18 of Set 3 | marysville
# Processing Record 19 of Set 3 | sambava
# Processing Record 20 of Set 3 | mersing
# Processing Record 21 of Set 3 | raudeberg
# Processing Record 22 of Set 3 | baruun-urt
# Processing Record 23 of Set 3 | abu kamal
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | puerto madryn
# Processing Record 26 of Set 3 | aasiaat
# Processing Record 27 of Set 3 | quibdo
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | san carlos de bariloche
# Processing Record 31 of Set 3 | umm lajj
# Processing Record 32 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 3 | scarborough
# Processing Record 35 of Set 3 | qasigiannguit
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | flinders
# Processing Record 38 of Set 3 | mangrol
# Processing Record 39 of Set 3 | korla
# Processing Record 40 of Set 3 | arlit
# Processing Record 41 of Set 3 | el balyana
# City not found. Skipping...
# Processing Record 42 of Set 3 | tomatlan
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | mbanza-ngungu
# Processing Record 45 of Set 3 | warwick
# Processing Record 46 of Set 3 | pemba
# Processing Record 47 of Set 3 | oranjemund
# Processing Record 48 of Set 3 | puerto ayacucho
# Processing Record 49 of Set 3 | saint-philippe
# Processing Record 50 of Set 3 | mafra
# Processing Record 1 of Set 4 | praia da vitoria
# Processing Record 2 of Set 4 | ostrovnoy
# Processing Record 3 of Set 4 | mount gambier
# Processing Record 4 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 4 | tuktoyaktuk
# Processing Record 6 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 4 | hirado
# Processing Record 8 of Set 4 | acapulco
# Processing Record 9 of Set 4 | dakar
# Processing Record 10 of Set 4 | sampit
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | kakamigahara
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | remedios
# Processing Record 15 of Set 4 | nanortalik
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | ust-omchug
# Processing Record 19 of Set 4 | meulaboh
# Processing Record 20 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | xai-xai
# Processing Record 23 of Set 4 | yamnytsya
# Processing Record 24 of Set 4 | nong han
# Processing Record 25 of Set 4 | cah ab
# City not found. Skipping...
# Processing Record 26 of Set 4 | porbandar
# Processing Record 27 of Set 4 | carnarvon
# Processing Record 28 of Set 4 | poum
# Processing Record 29 of Set 4 | sinnamary
# Processing Record 30 of Set 4 | barrow
# Processing Record 31 of Set 4 | coahuayana
# Processing Record 32 of Set 4 | ponta do sol
# Processing Record 33 of Set 4 | ankara
# Processing Record 34 of Set 4 | kavieng
# Processing Record 35 of Set 4 | asau
# Processing Record 36 of Set 4 | aktau
# Processing Record 37 of Set 4 | morehead
# Processing Record 38 of Set 4 | sorong
# Processing Record 39 of Set 4 | myitkyina
# Processing Record 40 of Set 4 | horsham
# Processing Record 41 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | nikolskoye
# Processing Record 44 of Set 4 | goure
# Processing Record 45 of Set 4 | beloha
# Processing Record 46 of Set 4 | lakes entrance
# Processing Record 47 of Set 4 | providencia
# Processing Record 48 of Set 4 | purpe
# Processing Record 49 of Set 4 | carauari
# Processing Record 50 of Set 4 | puerto ayora
# Processing Record 1 of Set 5 | faanui
# Processing Record 2 of Set 5 | necochea
# Processing Record 3 of Set 5 | qaqortoq
# Processing Record 4 of Set 5 | namibe
# Processing Record 5 of Set 5 | laela
# Processing Record 6 of Set 5 | nsanje
# Processing Record 7 of Set 5 | mombaca
# Processing Record 8 of Set 5 | dingle
# Processing Record 9 of Set 5 | talcahuano
# Processing Record 10 of Set 5 | ambunti
# Processing Record 11 of Set 5 | coquimbo
# Processing Record 12 of Set 5 | okhotsk
# Processing Record 13 of Set 5 | takoradi
# Processing Record 14 of Set 5 | ulladulla
# Processing Record 15 of Set 5 | taungdwingyi
# Processing Record 16 of Set 5 | dudinka
# Processing Record 17 of Set 5 | anori
# Processing Record 18 of Set 5 | koutsouras
# Processing Record 19 of Set 5 | namatanai
# Processing Record 20 of Set 5 | wanning
# Processing Record 21 of Set 5 | kruisfontein
# Processing Record 22 of Set 5 | quatre cocos
# Processing Record 23 of Set 5 | turukhansk
# Processing Record 24 of Set 5 | sayyan
# Processing Record 25 of Set 5 | loreto
# Processing Record 26 of Set 5 | angoche
# Processing Record 27 of Set 5 | kununurra
# Processing Record 28 of Set 5 | ketchikan
# Processing Record 29 of Set 5 | banda aceh
# Processing Record 30 of Set 5 | ryotsu
# Processing Record 31 of Set 5 | calatayud
# Processing Record 32 of Set 5 | saint-francois
# Processing Record 33 of Set 5 | moerai
# Processing Record 34 of Set 5 | henties bay
# Processing Record 35 of Set 5 | victoria
# Processing Record 36 of Set 5 | thompson
# Processing Record 37 of Set 5 | san cristobal
# Processing Record 38 of Set 5 | tashtagol
# Processing Record 39 of Set 5 | bontang
# Processing Record 40 of Set 5 | tual
# Processing Record 41 of Set 5 | alofi
# Processing Record 42 of Set 5 | cherskiy
# Processing Record 43 of Set 5 | bacolod
# Processing Record 44 of Set 5 | peniche
# Processing Record 45 of Set 5 | paamiut
# Processing Record 46 of Set 5 | jalu
# Processing Record 47 of Set 5 | olafsvik
# Processing Record 48 of Set 5 | ust-tsilma
# Processing Record 49 of Set 5 | yugorsk
# Processing Record 50 of Set 5 | boa esperanca
# Processing Record 1 of Set 6 | egvekinot
# Processing Record 2 of Set 6 | saskylakh
# Processing Record 3 of Set 6 | pimentel
# Processing Record 4 of Set 6 | rimbey
# Processing Record 5 of Set 6 | xianyang
# Processing Record 6 of Set 6 | serta
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | weihe
# Processing Record 9 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 6 | codrington
# Processing Record 11 of Set 6 | mfou
# Processing Record 12 of Set 6 | lumeje
# Processing Record 13 of Set 6 | morant bay
# Processing Record 14 of Set 6 | avarua
# Processing Record 15 of Set 6 | baft
# Processing Record 16 of Set 6 | sur
# Processing Record 17 of Set 6 | deputatskiy
# Processing Record 18 of Set 6 | kudahuvadhoo
# Processing Record 19 of Set 6 | port hardy
# Processing Record 20 of Set 6 | labuhan
# Processing Record 21 of Set 6 | mahibadhoo
# Processing Record 22 of Set 6 | longyearbyen
# Processing Record 23 of Set 6 | aksu
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | ginda
# Processing Record 26 of Set 6 | panlaitan
# Processing Record 27 of Set 6 | yerbogachen
# Processing Record 28 of Set 6 | port alfred
# Processing Record 29 of Set 6 | le port
# Processing Record 30 of Set 6 | kholtoson
# Processing Record 31 of Set 6 | kifri
# Processing Record 32 of Set 6 | asyut
# Processing Record 33 of Set 6 | jamestown
# Processing Record 34 of Set 6 | kamenka
# Processing Record 35 of Set 6 | kindu
# Processing Record 36 of Set 6 | urkut
# Processing Record 37 of Set 6 | suntar
# Processing Record 38 of Set 6 | balaipungut
# Processing Record 39 of Set 6 | vestmanna
# Processing Record 40 of Set 6 | beringovskiy
# Processing Record 41 of Set 6 | bereda
# Processing Record 42 of Set 6 | clarence town
# Processing Record 43 of Set 6 | pisco
# Processing Record 44 of Set 6 | mitsamiouli
# Processing Record 45 of Set 6 | parthenay
# Processing Record 46 of Set 6 | ponta delgada
# Processing Record 47 of Set 6 | keetmanshoop
# Processing Record 48 of Set 6 | road town
# Processing Record 49 of Set 6 | bethel
# Processing Record 50 of Set 6 | aldan
# Processing Record 1 of Set 7 | shimoda
# Processing Record 2 of Set 7 | havoysund
# Processing Record 3 of Set 7 | narsipatnam
# Processing Record 4 of Set 7 | port keats
# Processing Record 5 of Set 7 | taoudenni
# Processing Record 6 of Set 7 | le vauclin
# Processing Record 7 of Set 7 | greeley
# Processing Record 8 of Set 7 | ambon
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | neiafu
# Processing Record 11 of Set 7 | omboue
# Processing Record 12 of Set 7 | peleduy
# Processing Record 13 of Set 7 | hambantota
# Processing Record 14 of Set 7 | geraldton
# Processing Record 15 of Set 7 | bambous virieux
# Processing Record 16 of Set 7 | mount isa
# Processing Record 17 of Set 7 | bazarnyy karabulak
# Processing Record 18 of Set 7 | katsuura
# Processing Record 19 of Set 7 | casablanca
# Processing Record 20 of Set 7 | taksimo
# Processing Record 21 of Set 7 | oranjestad
# Processing Record 22 of Set 7 | naze
# Processing Record 23 of Set 7 | fortuna
# Processing Record 24 of Set 7 | kaohsiung
# Processing Record 25 of Set 7 | la ronge
# Processing Record 26 of Set 7 | hof
# Processing Record 27 of Set 7 | sao joao da barra
# Processing Record 28 of Set 7 | port blair
# Processing Record 29 of Set 7 | tecoanapa
# Processing Record 30 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 7 | lana
# Processing Record 32 of Set 7 | luz
# Processing Record 33 of Set 7 | alappuzha
# Processing Record 34 of Set 7 | pontianak
# Processing Record 35 of Set 7 | rawson
# Processing Record 36 of Set 7 | virtsu
# Processing Record 37 of Set 7 | bilma
# Processing Record 38 of Set 7 | hauterive
# Processing Record 39 of Set 7 | tilichiki
# Processing Record 40 of Set 7 | pontiac
# Processing Record 41 of Set 7 | kongwa
# Processing Record 42 of Set 7 | barcelona
# Processing Record 43 of Set 7 | borogontsy
# Processing Record 44 of Set 7 | baltiysk
# Processing Record 45 of Set 7 | daru
# Processing Record 46 of Set 7 | issaquah
# Processing Record 47 of Set 7 | cidreira
# Processing Record 48 of Set 7 | zhoucheng
# Processing Record 49 of Set 7 | dunedin
# Processing Record 50 of Set 7 | campoverde
# Processing Record 1 of Set 8 | nzega
# Processing Record 2 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 3 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 4 of Set 8 | palmer
# Processing Record 5 of Set 8 | altea
# Processing Record 6 of Set 8 | gat
# Processing Record 7 of Set 8 | san policarpo
# Processing Record 8 of Set 8 | richards bay
# Processing Record 9 of Set 8 | hofn
# Processing Record 10 of Set 8 | santa adelia
# Processing Record 11 of Set 8 | manacor
# Processing Record 12 of Set 8 | teahupoo
# Processing Record 13 of Set 8 | kaduqli
# Processing Record 14 of Set 8 | moussoro
# Processing Record 15 of Set 8 | iqaluit
# Processing Record 16 of Set 8 | feijo
# Processing Record 17 of Set 8 | nogent-le-rotrou
# Processing Record 18 of Set 8 | torbay
# Processing Record 19 of Set 8 | olyka
# Processing Record 20 of Set 8 | sonneberg
# Processing Record 21 of Set 8 | ekuvukeni
# Processing Record 22 of Set 8 | atar
# Processing Record 23 of Set 8 | dekalb
# Processing Record 24 of Set 8 | vila
# Processing Record 25 of Set 8 | presidencia roque saenz pena
# Processing Record 26 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 8 | japura
# Processing Record 28 of Set 8 | chara
# Processing Record 29 of Set 8 | negotin
# Processing Record 30 of Set 8 | seoul
# Processing Record 31 of Set 8 | coos bay
# Processing Record 32 of Set 8 | bagotville
# Processing Record 33 of Set 8 | terrace
# Processing Record 34 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 8 | alexandroupoli
# Processing Record 36 of Set 8 | okha
# Processing Record 37 of Set 8 | shakawe
# Processing Record 38 of Set 8 | vrsac
# Processing Record 39 of Set 8 | palana
# Processing Record 40 of Set 8 | manati
# Processing Record 41 of Set 8 | opuwo
# Processing Record 42 of Set 8 | tongliao
# Processing Record 43 of Set 8 | saint-augustin
# Processing Record 44 of Set 8 | alekseyevsk
# Processing Record 45 of Set 8 | deniliquin
# Processing Record 46 of Set 8 | whitehorse
# Processing Record 47 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 8 | vityazevo
# Processing Record 49 of Set 8 | muzhi
# Processing Record 50 of Set 8 | springbok
# Processing Record 1 of Set 9 | saint-louis
# Processing Record 2 of Set 9 | bubaque
# Processing Record 3 of Set 9 | chandpur
# Processing Record 4 of Set 9 | nyurba
# Processing Record 5 of Set 9 | bagan
# Processing Record 6 of Set 9 | jacqueville
# Processing Record 7 of Set 9 | juan lacaze
# Processing Record 8 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 9 of Set 9 | washington
# Processing Record 10 of Set 9 | klaksvik
# Processing Record 11 of Set 9 | sabang
# Processing Record 12 of Set 9 | tuatapere
# Processing Record 13 of Set 9 | bathsheba
# Processing Record 14 of Set 9 | buchanan
# Processing Record 15 of Set 9 | cabedelo
# Processing Record 16 of Set 9 | pedreiras
# Processing Record 17 of Set 9 | pedernales
# Processing Record 18 of Set 9 | tautira
# Processing Record 19 of Set 9 | seymchan
# Processing Record 20 of Set 9 | asfi
# Processing Record 21 of Set 9 | xingyi
# Processing Record 22 of Set 9 | chapais
# Processing Record 23 of Set 9 | margate
# Processing Record 24 of Set 9 | adwa
# Processing Record 25 of Set 9 | bud
# Processing Record 26 of Set 9 | nouakchott
# Processing Record 27 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 9 | lompoc
# Processing Record 29 of Set 9 | kondinskoye
# Processing Record 30 of Set 9 | lopukhiv
# Processing Record 31 of Set 9 | brae
# Processing Record 32 of Set 9 | pervomayskiy
# Processing Record 33 of Set 9 | lavrentiya
# Processing Record 34 of Set 9 | awbari
# Processing Record 35 of Set 9 | kidal
# Processing Record 36 of Set 9 | columbus
# Processing Record 37 of Set 9 | lotofaga
# Processing Record 38 of Set 9 | vila franca do campo
# Processing Record 39 of Set 9 | alta floresta
# Processing Record 40 of Set 9 | mercedes
# Processing Record 41 of Set 9 | mlowo
# Processing Record 42 of Set 9 | constantine
# Processing Record 43 of Set 9 | manokwari
# Processing Record 44 of Set 9 | saldanha
# Processing Record 45 of Set 9 | helena
# Processing Record 46 of Set 9 | cockburn town
# Processing Record 47 of Set 9 | northam
# Processing Record 48 of Set 9 | kurilsk
# Processing Record 49 of Set 9 | irati
# Processing Record 50 of Set 9 | hami
# Processing Record 1 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 10 | djambala
# Processing Record 4 of Set 10 | lata
# Processing Record 5 of Set 10 | berbera
# Processing Record 6 of Set 10 | souillac
# Processing Record 7 of Set 10 | avera
# Processing Record 8 of Set 10 | great bend
# Processing Record 9 of Set 10 | umm kaddadah
# Processing Record 10 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 11 of Set 10 | muscatine
# Processing Record 12 of Set 10 | nizhniy baskunchak
# Processing Record 13 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 14 of Set 10 | campestre
# Processing Record 15 of Set 10 | itaituba
# Processing Record 16 of Set 10 | collie
# Processing Record 17 of Set 10 | zhanaozen
# Processing Record 18 of Set 10 | emerald
# Processing Record 19 of Set 10 | port moresby
# Processing Record 20 of Set 10 | koslan
# Processing Record 21 of Set 10 | iberia
# Processing Record 22 of Set 10 | iguape
# Processing Record 23 of Set 10 | shelburne
# Processing Record 24 of Set 10 | brewster
# Processing Record 25 of Set 10 | norman wells
# Processing Record 26 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 10 | samarai
# Processing Record 28 of Set 10 | pinsk
# Processing Record 29 of Set 10 | falmouth
# Processing Record 30 of Set 10 | patur
# Processing Record 31 of Set 10 | cap-aux-meules
# Processing Record 32 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 33 of Set 10 | kavkazskaya
# Processing Record 34 of Set 10 | liaocheng
# Processing Record 35 of Set 10 | kumluca
# Processing Record 36 of Set 10 | makakilo city
# Processing Record 37 of Set 10 | maumere
# Processing Record 38 of Set 10 | nyrob
# Processing Record 39 of Set 10 | caninde
# Processing Record 40 of Set 10 | gweta
# Processing Record 41 of Set 10 | houma
# Processing Record 42 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 43 of Set 10 | clyde river
# Processing Record 44 of Set 10 | hobyo
# Processing Record 45 of Set 10 | hirara
# Processing Record 46 of Set 10 | port augusta
# Processing Record 47 of Set 10 | sakakah
# Processing Record 48 of Set 10 | coari
# Processing Record 49 of Set 10 | nanlong
# Processing Record 50 of Set 10 | rovaniemi
# Processing Record 1 of Set 11 | bima
# Processing Record 2 of Set 11 | rorvik
# Processing Record 3 of Set 11 | sehore
# Processing Record 4 of Set 11 | la palma
# Processing Record 5 of Set 11 | araria
# Processing Record 6 of Set 11 | yumen
# Processing Record 7 of Set 11 | kulachi
# Processing Record 8 of Set 11 | badian
# Processing Record 9 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 11 | terrace bay
# Processing Record 11 of Set 11 | altamont
# Processing Record 12 of Set 11 | montoro
# Processing Record 13 of Set 11 | moratuwa
# Processing Record 14 of Set 11 | hasaki
# Processing Record 15 of Set 11 | horasan
# Processing Record 16 of Set 11 | sola
# Processing Record 17 of Set 11 | ayagoz
# Processing Record 18 of Set 11 | el dorado
# Processing Record 19 of Set 11 | vardo
# Processing Record 20 of Set 11 | luchenza
# Processing Record 21 of Set 11 | irricana
# Processing Record 22 of Set 11 | ures
# Processing Record 23 of Set 11 | puerto escondido
# Processing Record 24 of Set 11 | waingapu
# Processing Record 25 of Set 11 | bureya
# Processing Record 26 of Set 11 | hatillo
# Processing Record 27 of Set 11 | miandrivazo
# Processing Record 28 of Set 11 | keshan
# City not found. Skipping...
# Processing Record 29 of Set 11 | chase
# Processing Record 30 of Set 11 | tura
# Processing Record 31 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | oruro
# Processing Record 33 of Set 11 | laguna
# Processing Record 34 of Set 11 | puquio
# Processing Record 35 of Set 11 | nandgaon
# Processing Record 36 of Set 11 | nassau
# Processing Record 37 of Set 11 | gizo
# Processing Record 38 of Set 11 | havre-saint-pierre
# Processing Record 39 of Set 11 | nechanice
# Processing Record 40 of Set 11 | korsakov
# Processing Record 41 of Set 11 | oyama
# Processing Record 42 of Set 11 | bilibino
# Processing Record 43 of Set 11 | matara
# Processing Record 44 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 11 | pastavy
# Processing Record 46 of Set 11 | verkhnevilyuysk
# Processing Record 47 of Set 11 | andenes
# Processing Record 48 of Set 11 | roma
# Processing Record 49 of Set 11 | aklavik
# Processing Record 50 of Set 11 | port-gentil
# Processing Record 1 of Set 12 | qrendi
# Processing Record 2 of Set 12 | el tigre
# Processing Record 3 of Set 12 | yebaishou
# Processing Record 4 of Set 12 | te anau
# Processing Record 5 of Set 12 | hohhot
# Processing Record 6 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 12 | urucara
# Processing Record 8 of Set 12 | moree
# Processing Record 9 of Set 12 | boa vista
# Processing Record 10 of Set 12 | kathu
# Processing Record 11 of Set 12 | lajas
# Processing Record 12 of Set 12 | puri
# Processing Record 13 of Set 12 | puerto gaitan
# Processing Record 14 of Set 12 | lasa
# Processing Record 15 of Set 12 | panzhihua
# Processing Record 16 of Set 12 | katherine
# Processing Record 17 of Set 12 | dhidhdhoo
# Processing Record 18 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 19 of Set 12 | sakyla
# Processing Record 20 of Set 12 | moyale
# Processing Record 21 of Set 12 | orotukan
# Processing Record 22 of Set 12 | waipawa
# Processing Record 23 of Set 12 | santa isabel do rio negro
# Processing Record 24 of Set 12 | vredendal
# Processing Record 25 of Set 12 | sechura
# Processing Record 26 of Set 12 | comodoro rivadavia
# Processing Record 27 of Set 12 | dax
# Processing Record 28 of Set 12 | bataipora
# Processing Record 29 of Set 12 | huanan
# Processing Record 30 of Set 12 | nurota
# Processing Record 31 of Set 12 | kapchorwa
# Processing Record 32 of Set 12 | grimshaw
# Processing Record 33 of Set 12 | hay river
# Processing Record 34 of Set 12 | saint anthony
# Processing Record 35 of Set 12 | mirina
# City not found. Skipping...
# Processing Record 36 of Set 12 | wuwei
# Processing Record 37 of Set 12 | pacific grove
# Processing Record 38 of Set 12 | inhambane
# Processing Record 39 of Set 12 | camambugan
# Processing Record 40 of Set 12 | kulhudhuffushi
# Processing Record 41 of Set 12 | leningradskiy
# Processing Record 42 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 12 | kiama
# Processing Record 44 of Set 12 | dukat
# Processing Record 45 of Set 12 | maningrida
# Processing Record 46 of Set 12 | pokanayevka
# City not found. Skipping...
# Processing Record 47 of Set 12 | sanary-sur-mer
# Processing Record 48 of Set 12 | burica
# City not found. Skipping...
# Processing Record 49 of Set 12 | nikolsk
# Processing Record 50 of Set 12 | tres arroyos
# Processing Record 1 of Set 13 | vestmannaeyjar
# Processing Record 2 of Set 13 | prado
# Processing Record 3 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 13 | port hedland
# Processing Record 5 of Set 13 | bella vista
# Processing Record 6 of Set 13 | port lincoln
# Processing Record 7 of Set 13 | lubbock
# Processing Record 8 of Set 13 | lagos
# Processing Record 9 of Set 13 | kirakira
# Processing Record 10 of Set 13 | crib point
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Half Moon Bay  37.4636 -122.4286     78.75        78           1
# 1        Ushuaia -54.8000  -68.3000     38.86        75          75
# 2      Caravelas -17.7125  -39.2481     68.31        68           2
# 3          Adrar  20.5022  -10.0711     89.67        22          73
# 4         Vostok  46.4856  135.8833     93.45        36          49
# 5  Srednekolymsk  67.4500  153.6833     64.04        40         100
# 6     Kaitangata -46.2817  169.8464     49.93        53          96
# 7          Vaini -21.2000 -175.2000     77.16        94          20
# 8       Oussouye  12.4850  -16.5469     77.86        78          95
# 9         Acarau  -2.8856  -40.1200     75.74        81           5
#
#    Wind Speed Country Current Description                 Date
# 0        1.01      US           clear sky  2021-07-25 03:26:19
# 1        2.30      AR       broken clouds  2021-07-25 03:24:20
# 2        5.44      BR           clear sky  2021-07-25 03:26:19
# 3        9.24      MR       broken clouds  2021-07-25 03:26:20
# 4        4.45      RU    scattered clouds  2021-07-25 03:26:20
# 5       13.53      RU     overcast clouds  2021-07-25 03:26:20
# 6       10.11      NZ     overcast clouds  2021-07-25 03:26:21
# 7        9.22      TO          light rain  2021-07-25 03:26:21
# 8        4.99      SN          light rain  2021-07-25 03:26:22
# 9       11.56      BR           clear sky  2021-07-25 03:26:22

# %%
new_column_order =["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Half Moon Bay      US  37.4636 -122.4286     78.75        78           1
# 1          Ushuaia      AR -54.8000  -68.3000     38.86        75          75
# 2        Caravelas      BR -17.7125  -39.2481     68.31        68           2
# 3            Adrar      MR  20.5022  -10.0711     89.67        22          73
# 4           Vostok      RU  46.4856  135.8833     93.45        36          49
# ..             ...     ...      ...       ...       ...       ...         ...
# 556   Port Lincoln      AU -34.7333  135.8667     59.13        74          44
# 557        Lubbock      US  33.6001 -101.8338     86.38        52          20
# 558          Lagos      NG   6.5833    3.7500     77.32        87           7
# 559       Kirakira      SB -10.4544  161.9205     83.57        77          51
# 560     Crib Point      AU -38.3500  145.2000     53.92        71          95
#
#      Wind Speed Current Description
# 0          1.01           clear sky
# 1          2.30       broken clouds
# 2          5.44           clear sky
# 3          9.24       broken clouds
# 4          4.45    scattered clouds
# ..          ...                 ...
# 556       27.11    scattered clouds
# 557        3.00          few clouds
# 558        2.66           clear sky
# 559        9.10          light rain
# 560       25.21     overcast clouds
#
# [561 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
